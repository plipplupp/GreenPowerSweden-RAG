# %%
import os
import shutil
from pathlib import Path
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from tqdm import tqdm

# 1. Sökvägar
BASE_DIR = Path(r"C:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden")
TEXT_SOURCE_DIR = BASE_DIR / "data" / "02_processed" / "extracted_text"
DB_OUTPUT_DIR = BASE_DIR / "data" / "03_vector_db" / "green_power_sweden_db_local"

# 2. Modell
print("Laddar modell...")
embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-mpnet-base-v2",
    model_kwargs={'device': 'cpu'} 
)

# 3. Läs filer
print(f"Läser textfiler från {TEXT_SOURCE_DIR}...")
documents = []
all_files = list(TEXT_SOURCE_DIR.rglob("*.txt"))

if not all_files:
    print("FEL: Hittade inga textfiler! Har du packat upp dem lokalt?")
    exit()

for file_path in tqdm(all_files, desc="Läser filer"):
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            text = f.read()
        # Skapa metadata från filnamnet
        source_name = file_path.name.replace(".txt", "")
        documents.append(Document(page_content=text, metadata={"source": source_name}))
    except Exception:
        continue

print(f"Laddade {len(documents)} dokument.")

# 4. Chunka
print("Chunkar dokument...")
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=2000,
    chunk_overlap=400,
    separators=["\n\n", "\n", " ", ""]
)
chunks = text_splitter.split_documents(documents)
print(f"Skapade {len(chunks)} chunks.")

# 5. Bygg databas (Batchat för att spara minne)
print(f"Bygger databas i {DB_OUTPUT_DIR}...")
if DB_OUTPUT_DIR.exists():
    shutil.rmtree(DB_OUTPUT_DIR) # Rensa gammalt försök

vectordb = Chroma(
    persist_directory=str(DB_OUTPUT_DIR),
    embedding_function=embedding_model
)

BATCH_SIZE = 100 # Mindre batcher för din dators skull
total_chunks = len(chunks)

for i in tqdm(range(0, total_chunks, BATCH_SIZE), desc="Skapar embeddings"):
    batch = chunks[i:i + BATCH_SIZE]
    vectordb.add_documents(batch)

print("Klar! Databasen är byggd lokalt och kompatibel.")
# Out:
# Laddar modell...
# Läser textfiler från C:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\data\02_processed\extracted_text...
# Läser filer: 100%|██████████| 4483/4483 [00:05<00:00, 870.15it/s]
# Laddade 4483 dokument.
# Chunkar dokument...
# Skapade 165583 chunks.
# Bygger databas i C:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\data\03_vector_db\green_power_sweden_db_local...
# Skapar embeddings:   0%|          | 6/1656 [21:21<97:51:28, 213.51s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 68
#      66 for i in tqdm(range(0, total_chunks, BATCH_SIZE), desc="Skapar embeddings"):
#      67     batch = chunks[i:i + BATCH_SIZE]
# ---> 68     vectordb.add_documents(batch)
#      70 print("Klar! Databasen är byggd lokalt och kompatibel.")
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\langchain_core\vectorstores\base.py:257, in VectorStore.add_documents(self, documents, **kwargs)
#     255     texts = [doc.page_content for doc in documents]
#     256     metadatas = [doc.metadata for doc in documents]
# --> 257     return self.add_texts(texts, metadatas, **kwargs)
#     258 msg = (
#     259     f"`add_documents` and `add_texts` has not been implemented "
#     260     f"for {self.__class__.__name__} "
#     261 )
#     262 raise NotImplementedError(msg)
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\langchain_chroma\vectorstores.py:620, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     618 texts = list(texts)
#     619 if self._embedding_function is not None:
# --> 620     embeddings = self._embedding_function.embed_documents(texts)
#     621 if metadatas:
#     622     # fill metadatas with empty dicts if somebody
#     623     # did not specify metadata for all texts
#     624     length_diff = len(texts) - len(metadatas)
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:155, in HuggingFaceEmbeddings.embed_documents(self, texts)
#     145 def embed_documents(self, texts: list[str]) -> list[list[float]]:
#     146     """Compute doc embeddings using a HuggingFace transformer model.
#     147
#     148     Args:
#    (...)    153
#     154     """
# --> 155     return self._embed(texts, self.encode_kwargs)
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:130, in HuggingFaceEmbeddings._embed(self, texts, encode_kwargs)
#     128     sentence_transformers.SentenceTransformer.stop_multi_process_pool(pool)
#     129 else:
# --> 130     embeddings = self._client.encode(
#     131         texts,
#     132         show_progress_bar=self.show_progress,
#     133         **encode_kwargs,
#     134     )
#     136 if isinstance(embeddings, list):
#     137     msg = (
#     138         "Expected embeddings to be a Tensor or a numpy array, "
#     139         "got a list instead."
#     140     )
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\sentence_transformers\SentenceTransformer.py:1094, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#    1091 features.update(extra_features)
#    1093 with torch.no_grad():
# -> 1094     out_features = self.forward(features, **kwargs)
#    1095     if self.device.type == "hpu":
#    1096         out_features = copy.deepcopy(out_features)
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\sentence_transformers\SentenceTransformer.py:1175, in SentenceTransformer.forward(self, input, **kwargs)
#    1169             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#    1170         module_kwargs = {
#    1171             key: value
#    1172             for key, value in kwargs.items()
#    1173             if key in module_kwarg_keys or (hasattr(module, "forward_kwargs") and key in module.forward_kwargs)
#    1174         }
# -> 1175     input = module(input, **module_kwargs)
#    1176 return input
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\sentence_transformers\models\Transformer.py:261, in Transformer.forward(self, features, **kwargs)
#     238 """
#     239 Forward pass through the transformer model.
#     240
#    (...)    257         - 'all_layer_embeddings': If the model outputs hidden states, contains embeddings from all layers
#     258 """
#     259 trans_features = {key: value for key, value in features.items() if key in self.model_forward_params}
# --> 261 outputs = self.auto_model(**trans_features, **kwargs, return_dict=True)
#     262 token_embeddings = outputs[0]
#     263 features["token_embeddings"] = token_embeddings
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\transformers\models\mpnet\modeling_mpnet.py:486, in MPNetModel.forward(self, input_ids, attention_mask, position_ids, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict, **kwargs)
#     484 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     485 embedding_output = self.embeddings(input_ids=input_ids, position_ids=position_ids, inputs_embeds=inputs_embeds)
# --> 486 encoder_outputs = self.encoder(
#     487     embedding_output,
#     488     attention_mask=extended_attention_mask,
#     489     head_mask=head_mask,
#     490     output_attentions=output_attentions,
#     491     output_hidden_states=output_hidden_states,
#     492     return_dict=return_dict,
#     493 )
#     494 sequence_output = encoder_outputs[0]
#     495 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\transformers\models\mpnet\modeling_mpnet.py:338, in MPNetEncoder.forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states, return_dict, **kwargs)
#     335 if output_hidden_states:
#     336     all_hidden_states = all_hidden_states + (hidden_states,)
# --> 338 layer_outputs = layer_module(
#     339     hidden_states,
#     340     attention_mask,
#     341     head_mask[i],
#     342     position_bias,
#     343     output_attentions=output_attentions,
#     344     **kwargs,
#     345 )
#     346 hidden_states = layer_outputs[0]
#     348 if output_attentions:
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\transformers\models\mpnet\modeling_mpnet.py:297, in MPNetLayer.forward(self, hidden_states, attention_mask, head_mask, position_bias, output_attentions, **kwargs)
#     288 def forward(
#     289     self,
#     290     hidden_states,
#    (...)    295     **kwargs,
#     296 ):
# --> 297     self_attention_outputs = self.attention(
#     298         hidden_states,
#     299         attention_mask,
#     300         head_mask,
#     301         position_bias=position_bias,
#     302         output_attentions=output_attentions,
#     303     )
#     304     attention_output = self_attention_outputs[0]
#     305     outputs = self_attention_outputs[1:]  # add self attentions if we output attention weights
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\transformers\models\mpnet\modeling_mpnet.py:238, in MPNetAttention.forward(self, hidden_states, attention_mask, head_mask, position_bias, output_attentions, **kwargs)
#     229 def forward(
#     230     self,
#     231     hidden_states,
#    (...)    236     **kwargs,
#     237 ):
# --> 238     self_outputs = self.attn(
#     239         hidden_states,
#     240         attention_mask,
#     241         head_mask,
#     242         position_bias,
#     243         output_attentions=output_attentions,
#     244     )
#     245     attention_output = self.LayerNorm(self.dropout(self_outputs[0]) + hidden_states)
#     246     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\transformers\models\mpnet\modeling_mpnet.py:185, in MPNetSelfAttention.forward(self, hidden_states, attention_mask, head_mask, position_bias, output_attentions, **kwargs)
#     182     attention_scores = attention_scores + attention_mask
#     184 # Normalize the attention scores to probabilities.
# --> 185 attention_probs = nn.functional.softmax(attention_scores, dim=-1)
#     187 attention_probs = self.dropout(attention_probs)
#     189 if head_mask is not None:
#
# File c:\Users\Dator\Documents\Data_Science\11_Examensarbete\green_power_sweden\.venv\Lib\site-packages\torch\nn\functional.py:2133, in softmax(input, dim, _stacklevel, dtype)
#    2131     dim = _get_softmax_dim("softmax", input.dim(), _stacklevel)
#    2132 if dtype is None:
# -> 2133     ret = input.softmax(dim)
#    2134 else:
#    2135     ret = input.softmax(dim, dtype=dtype)
#
# KeyboardInterrupt:
